# %%
import pandas as pd
food_nutrient = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Dokumenty\CZECHITAS-LAPTOP-BTGJD9J5\Python pro datovou analýzu\food_nutrient.csv") # načtení dat
duplicates = food_nutrient[food_nutrient.duplicated(subset=['fdc_id', 'name'], keep=False)] # vyfiltrování duplicitních hodnot
food_nutrient = food_nutrient.drop_duplicates(subset=["fdc_id", "name"]) # odstranění duplikátů
food_nutrient_pivot = pd.pivot(food_nutrient, index="fdc_id", columns="name", values="amount") # přeskládání tabulky funkcní pivot
branded_food = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Dokumenty\CZECHITAS-LAPTOP-BTGJD9J5\Python pro datovou analýzu\data\branded_food.csv")
food = pd.concat([pd.read_csv(r"C:\Users\Lenovo\OneDrive\Dokumenty\CZECHITAS-LAPTOP-BTGJD9J5\Python pro datovou analýzu\data\food_sample_100.csv"), pd.read_csv(r"C:\Users\Lenovo\OneDrive\Dokumenty\CZECHITAS-LAPTOP-BTGJD9J5\Python pro datovou analýzu\data\food_other.csv")], ignore_index=True) # spojení tabulek do jedné tabulky food
food_brands = pd.merge(food, branded_food, on="fdc_id") #spojení tabulek food a branded_food
food_nutrient_pivot = pd.merge(food_nutrient_pivot, branded_food, on="fdc_id")

food_nutrient_pivot
# Out:
#        fdc_id   Ergosta-5,7-dienol  25-hydroxycholecalciferol  Alanine  \
# 0      344774                  NaN                        NaN      NaN
# 1      344980                  NaN                        NaN      NaN
# 2      345013                  NaN                        NaN      NaN
# 3      345215                  NaN                        NaN      NaN
# 4      345449                  NaN                        NaN      NaN
# ...       ...                  ...                        ...      ...
# 9536  2661515                  NaN                        NaN      NaN
# 9537  2661730                  NaN                        NaN      NaN
# 9538  2661782                  NaN                        NaN      NaN
# 9539  2662107                  NaN                        NaN      NaN
# 9540  2662182                  NaN                        NaN      NaN
#
#       Alcohol, ethyl  Arginine  Ash  Aspartic acid  Beta-glucan  \
# ...

# %%
food_nutrient_pivot[(food_nutrient_pivot["Fatty acids, total saturated"] < 1) & (food_nutrient_pivot["Fiber, total dietary"] > 5)]
# Out:
#        fdc_id   Ergosta-5,7-dienol  25-hydroxycholecalciferol  Alanine  \
# 2      345013                  NaN                        NaN      NaN
# 4      345449                  NaN                        NaN      NaN
# 7      345947                  NaN                        NaN      NaN
# 79     357444                  NaN                        NaN      NaN
# 115    364184                  NaN                        NaN      NaN
# ...       ...                  ...                        ...      ...
# 9441  2639399                  NaN                        NaN      NaN
# 9451  2641652                  NaN                        NaN      NaN
# 9474  2651138                  NaN                        NaN      NaN
# 9476  2651678                  NaN                        NaN      NaN
# 9506  2655929                  NaN                        NaN      NaN
#
#       Alcohol, ethyl  Arginine  Ash  Aspartic acid  Beta-glucan  \
# ...
